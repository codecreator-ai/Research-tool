# %% [markdown]
# <a href="https://colab.research.google.com/github/codecreator-ai/Research-tool/blob/main/Harvest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
import os
drive.mount('/content/drive')
BASE_PATH = '/content/drive/MyDrive/paper-harvest-2025'
os.makedirs(f'{BASE_PATH}/data/raw', exist_ok=True)
os.makedirs(f'{BASE_PATH}/data/pdfs', exist_ok=True)
os.makedirs(f'{BASE_PATH}/data/outputs', exist_ok=True)
os.makedirs(f'{BASE_PATH}/logs', exist_ok=True)
print(f"Project directory: {BASE_PATH}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Project directory: /content/drive/MyDrive/paper-harvest-2025

# %%
from google.colab import userdata
import getpass
try:
    SEMANTIC_SCHOLAR_API_KEY = userdata.get('SEMANTIC_SCHOLAR_API_KEY')
    UNPAYWALL_EMAIL = userdata.get('EMAIL_ADDRESS')
    print("Loaded credentials from Colab Secrets")
except:
    print("Colab Secrets not found. Manual input required:")
    SEMANTIC_SCHOLAR_API_KEY = getpass.getpass("Semantic Scholar API Key: ")
    UNPAYWALL_EMAIL = input("Your email for Unpaywall: ")

CROSSREF_MAILTO = UNPAYWALL_EMAIL
EUROPE_PMC_API_KEY = ''

# Pipeline configuration
MAX_PAPERS = 2000
TARGET_YEAR = 2025

print(f"Target year: {TARGET_YEAR}, Max papers: {MAX_PAPERS}")
# Out:
# Loaded credentials from Colab Secrets
# Target year: 2025, Max papers: 2000

# %%
import requests
import pandas as pd
import json
import re
import time
import logging
from datetime import datetime
from typing import Optional, Tuple, List, Dict
from tqdm.auto import tqdm
from bs4 import BeautifulSoup
from tenacity import retry, stop_after_attempt, wait_exponential, retry_if_exception_type
import unicodedata  # Built-in Python module - replaces unidecode
from io import BytesIO, StringIO

# PDF extraction imports - use correct pdfminer.six paths
try:
    from pdfminer.high_level import extract_text
    PDFMINER_AVAILABLE = True
except ImportError:
    try:
        from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
        from pdfminer.converter import TextConverter
        from pdfminer.layout import LAParams
        from pdfminer.pdfpage import PDFPage
        PDFMINER_AVAILABLE = True
    except ImportError:
        PDFMINER_AVAILABLE = False
        print("⚠️ Warning: pdfminer.six not available, PDF extraction will be skipped")

# Setup logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler(f'{BASE_PATH}/logs/run.log'),
        logging.StreamHandler()
    ]
)
logger = logging.getLogger(__name__)

# API Endpoints
SEMANTIC_SCHOLAR_SEARCH_URL = "https://api.semanticscholar.org/graph/v1/paper/search"
SEMANTIC_SCHOLAR_PAPER_FIELDS = "title,abstract,authors,year,venue,url,externalIds"
CROSSREF_API_URL = "https://api.crossref.org/works"
EUROPE_PMC_SEARCH_URL = "https://www.ebi.ac.uk/europepmc/webservices/rest/search"
UNPAYWALL_URL = "https://api.unpaywall.org/v2/"

# HTTP Headers
HEADERS = {
    "User-Agent": f"paper-harvester/1.0 (mailto:{UNPAYWALL_EMAIL})"
}

# Rate limiting (seconds)
SS_REQUEST_SLEEP = 0.6
CR_REQUEST_SLEEP = 0.5
EPMC_REQUEST_SLEEP = 0.5
UNPAYWALL_SLEEP = 0.2
HTML_REQUEST_SLEEP = 1.2
PDF_REQUEST_SLEEP = 1.5

# Retry configuration
MAX_RETRIES = 5
BACKOFF_MULT = 2

# Regex patterns for extraction
EMAIL_RE = re.compile(r"\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Za-z]{2,}\b")
CORR_KEYWORDS_RE = re.compile(
    r"(corresponding author|correspondence to|correspondence:|to whom correspondence should be addressed|author for correspondence)",
    re.I
)
AFFILIATION_KEYWORDS = ["university", "college", "department", "institute", "school", "laboratory", "lab", "center"]

# Classification keywords
INDUSTRY_KEYWORDS = [
    "inc", "llc", "ltd", "gmbh", "co.", "corporation", "company", "biotech", "pharma",
    "amazon", "google", "microsoft", "deepmind", "novartis", "roche", "pfizer", "basf",
    "abbvie", "sanofi", "glaxosmithkline", "gsk", "johnson & johnson", "meta", "anthropic"
]

ACADEMIC_KEYWORDS = [
    "university", "college", "institute", "department", "school", "laboratory",
    "lab", "centr", "center", "faculty", "edu", "california"
]

# Search queries
QUERIES = [
    '("Deep Learning" OR "long short term memory") AND ("cellular differentiation") AND ("cell fate" OR "cell fate decision")',
    '("single-cell" OR "scRNA-seq" OR "single cell RNA") AND ("time series" OR "temporal") AND ("differentiation" OR "cell fate" OR "trajectory")',
    '("machine learning" OR "deep learning" OR "neural network") AND ("cell differentiation" OR "cell fate")',
    '("time series gene expression" OR "temporal gene expression") AND ("cell differentiation" OR "cell fate")',
    '("LSTM" OR "recurrent neural network") AND ("single-cell" OR "scRNA-seq")'
]

print("Constants and configuration loaded")
# Out:
# ⚠️ Warning: pdfminer.six not available, PDF extraction will be skipped
# Constants and configuration loaded

# %%
# %%bash
# source /usr/local/etc/profile.d/conda.sh
# conda activate myenv
# conda install unidecode -y
# Out:
# Jupyter detected...
# 2 channel Terms of Service accepted
# Channels:
#  - defaults
# Platform: linux-64
# done
# done
#
# # All requested packages already installed.

# %%
def normalize_doi(doi: str) -> Optional[str]:
    """Normalize DOI to lowercase, strip whitespace, remove prefix"""
    if not doi or doi.strip() == '':
        return None

    doi = doi.lower().strip()

    # Remove common prefixes
    if doi.startswith('doi:'):
        doi = doi[4:]
    elif doi.startswith('https://doi.org/'):
        doi = doi[16:]
    elif doi.startswith('http://doi.org/'):
        doi = doi[15:]

    return doi.strip() if doi.strip() else None


def normalize_title(title: str) -> str:
    """Normalize title: ASCII, lowercase, remove punctuation"""
    if not title:
        return ""

    # Unicode to ASCII using built-in unicodedata
    # NFKD = Compatibility Decomposition, then filter out non-ASCII
    normalized = unicodedata.normalize('NFKD', title)
    ascii_title = normalized.encode('ASCII', 'ignore').decode('ASCII')

    # Lowercase
    ascii_title = ascii_title.lower()

    # Remove punctuation
    ascii_title = re.sub(r'[,.;:!?()\[\]{}]', '', ascii_title)

    # Collapse whitespace
    ascii_title = re.sub(r'\s+', ' ', ascii_title)

    return ascii_title.strip()

def dedupe_and_filter_year(df: pd.DataFrame, year: int = 2025) -> pd.DataFrame:
    """Deduplicate by DOI/title and filter to target year"""
    logger.info(f"Starting deduplication. Input rows: {len(df)}")

    # Create normalized columns
    df['doi_norm'] = df['doi'].apply(normalize_doi)
    df['title_norm'] = df['title'].apply(normalize_title)

    # Filter by year first
    df = df[df['year'] == year].copy()
    logger.info(f"After year filter ({year}): {len(df)} rows")

    # Deduplicate by DOI where available
    df_with_doi = df[df['doi_norm'].notna()].copy()
    df_without_doi = df[df['doi_norm'].isna()].copy()

    df_with_doi = df_with_doi.drop_duplicates(subset=['doi_norm'], keep='first')
    df_without_doi = df_without_doi.drop_duplicates(subset=['title_norm'], keep='first')

    df_deduped = pd.concat([df_with_doi, df_without_doi], ignore_index=True)

    logger.info(f"After deduplication: {len(df_deduped)} rows")

    # Save
    output_path = f'{BASE_PATH}/data/outputs/papers_deduped.csv'
    df_deduped.to_csv(output_path, index=False, encoding='utf-8')
    logger.info(f"Saved to {output_path}")

    return df_deduped

print("Utility functions defined")
# Out:
# Utility functions defined

# %%
#@retry(
#    stop=stop_after_attempt(MAX_RETRIES),
#    wait=wait_exponential(multiplier=1, max=60),
#    retry=retry_if_exception_type((requests.exceptions.RequestException, requests.exceptions.Timeout))
#)
def semantic_scholar_search(query: str, offset: int, limit: int = 100) -> dict:
    """Search Semantic Scholar API with retry logic"""
    params = {
        'query': query,
        'offset': offset,
        'limit': limit,
        'fields': SEMANTIC_SCHOLAR_PAPER_FIELDS
    }

    headers = {
        **HEADERS,
        'x-api-key': SEMANTIC_SCHOLAR_API_KEY
    }

    response = requests.get(
        SEMANTIC_SCHOLAR_SEARCH_URL,
        params=params,
        headers=headers,
        timeout=30
    )

    if response.status_code == 429:
        logger.warning("Rate limited by Semantic Scholar, retrying...")
        raise requests.exceptions.RequestException("Rate limited")

    response.raise_for_status()
    time.sleep(SS_REQUEST_SLEEP)

    return response.json()

import re

def sanitize_query_for_ss(query: str) -> str:
    # remove quotes and parentheses and boolean operators, collapse spaces
    q = re.sub(r'["\(\)]', ' ', query)                       # remove quotes & parens
    q = re.sub(r'\b(AND|OR|NOT|&&|\|\|)\b', ' ', q, flags=re.I)  # remove boolean tokens
    q = re.sub(r'[-]', ' ', q)                               # replace hyphens (docs mention issues)
    q = re.sub(r'\s+', ' ', q).strip()
    return q

    # Usage in harvest_all:
    safe_query = sanitize_query_for_ss(query)
    result = semantic_scholar_search(safe_query, offset, limit=100)

def crossref_search_primary(query: str, rows: int = 100, offset: int = 0) -> dict:
    """Search CrossRef API - NO API KEY REQUIRED"""
    params = {
        'query': query,
        'filter': 'from-pub-date:2025-01-01,until-pub-date:2025-12-31',
        'rows': rows,
        'offset': offset,
        'mailto': UNPAYWALL_EMAIL  # Polite usage
    }

    try:
        response = requests.get(CROSSREF_API_URL, params=params, headers=HEADERS, timeout=30)
        response.raise_for_status()
        time.sleep(CR_REQUEST_SLEEP)
        return response.json()
    except Exception as e:
        logger.error(f"CrossRef error: {e}")
        return {}



@retry(
    stop=stop_after_attempt(MAX_RETRIES),
    wait=wait_exponential(multiplier=1, max=60),
    retry=retry_if_exception_type((requests.exceptions.RequestException,))
)
def crossref_search(query: str, rows: int = 100, offset: int = 0) -> dict:
    """Search CrossRef API"""
    params = {
        'query': query,
        'year' : TARGET_YEAR,
        'filter': 'from-pub-date:2025-01-01,until-pub-date:2025-12-31',
        'rows': rows,
        'offset': offset,
        'mailto': CROSSREF_MAILTO
    }

    response = requests.get(CROSSREF_API_URL, params=params, headers=HEADERS, timeout=30)
    response.raise_for_status()
    time.sleep(CR_REQUEST_SLEEP)

    return response.json()

def harvest_all_crossref(queries: List[str]) -> pd.DataFrame:
    """Harvest papers from CrossRef (no API key needed)"""
    all_papers = []
    total_harvested = 0

    logger.info(f"Starting CrossRef harvest with {len(queries)} queries")

    for query_idx, query in enumerate(queries):
        logger.info(f"Query {query_idx + 1}/{len(queries)}: {query[:80]}...")

        offset = 0

        while total_harvested < MAX_PAPERS:
            try:
                result = crossref_search_primary(query, rows=100, offset=offset)

                items = result.get('message', {}).get('items', [])
                if not items:
                    logger.info(f"No more results for query {query_idx + 1}")
                    break

                timestamp = datetime.utcnow().isoformat()

                for item in items:
                    # Extract author info
                    authors_list = []
                    for author in item.get('author', []):
                        authors_list.append({
                            'name': f"{author.get('given', '')} {author.get('family', '')}".strip()
                        })

                    paper_row = {
                        'ss_paper_id': None,  # CrossRef doesn't have this
                        'title': item.get('title', [''])[0] if item.get('title') else '',
                        'abstract': item.get('abstract', ''),  # Often not available in CrossRef
                        'doi': item.get('DOI'),
                        'year': item.get('published', {}).get('date-parts', [[None]])[0][0],
                        'venue': item.get('container-title', [''])[0] if item.get('container-title') else '',
                        'authors': json.dumps(authors_list),
                        'url': item.get('URL', ''),
                        'externalIds': json.dumps({'DOI': item.get('DOI')}),
                        'harvest_source': 'crossref',
                        'harvest_query': query,
                        'harvest_offset': offset,
                        'harvest_timestamp': timestamp
                    }
                    all_papers.append(paper_row)
                    total_harvested += 1

                    if total_harvested >= MAX_PAPERS:
                        break

                logger.info(f"Offset {offset}: fetched {len(items)} papers (total: {total_harvested})")
                offset += 100

                if total_harvested >= MAX_PAPERS:
                    logger.info(f"Reached MAX_PAPERS limit ({MAX_PAPERS})")
                    break

            except Exception as e:
                logger.error(f"Error harvesting query {query_idx + 1} at offset {offset}: {e}")
                break

        if total_harvested >= MAX_PAPERS:
            break

    df = pd.DataFrame(all_papers)

    # Save raw harvest
    output_path = f'{BASE_PATH}/data/outputs/papers_raw.csv'
    df.to_csv(output_path, index=False, encoding='utf-8')
    logger.info(f"Saved {len(df)} raw papers to {output_path}")

    return df

#@retry(
#    stop=stop_after_attempt(MAX_RETRIES),
#    wait=wait_exponential(multiplier=1, max=60),
#    retry=retry_if_exception_type((requests.exceptions.RequestException,))
#)
def europe_pmc_search(query: str, pageSize: int = 100, page: int = 1) -> dict:
    """Search Europe PMC API"""
    full_query = f'{query} PUB_YEAR:{TARGET_YEAR}'
    params = {
        'query': full_query,
        'format': 'json',
        'pageSize': pageSize,
        'page': page
    }

    response = requests.get(EUROPE_PMC_SEARCH_URL, params=params, headers=HEADERS, timeout=30)
    response.raise_for_status()
    time.sleep(EPMC_REQUEST_SLEEP)

    return response.json()


def harvest_all(queries: List[str]) -> pd.DataFrame:
    """Harvest papers from all sources"""
    all_papers = []
    total_harvested = 0

    logger.info(f"Starting harvest with {len(queries)} queries")

    for query_idx, query in enumerate(queries):
        logger.info(f"Query {query_idx + 1}/{len(queries)}: {query[:80]}...")

        offset = 0
        query_count = 0

        while total_harvested < MAX_PAPERS:
            try:
                safe_query = sanitize_query_for_ss(query)
                result = semantic_scholar_search(safe_query, offset, limit=100)

                papers = result.get('data', [])
                if not papers:
                    logger.info(f"No more results for query {query_idx + 1}")
                    break

                timestamp = datetime.utcnow().isoformat()

                for paper in papers:
                    paper_row = {
                        'ss_paper_id': paper.get('paperId'),
                        'title': paper.get('title'),
                        'abstract': paper.get('abstract'),
                        'doi': paper.get('externalIds', {}).get('DOI'),
                        'year': paper.get('year'),
                        'venue': paper.get('venue'),
                        'authors': json.dumps(paper.get('authors', [])),
                        'url': paper.get('url'),
                        'externalIds': json.dumps(paper.get('externalIds', {})),
                        'harvest_source': 'semantic_scholar',
                        'harvest_query': query,
                        'harvest_offset': offset,
                        'harvest_timestamp': timestamp
                    }
                    all_papers.append(paper_row)
                    query_count += 1
                    total_harvested += 1

                    if total_harvested >= MAX_PAPERS:
                        break

                logger.info(f"Offset {offset}: fetched {len(papers)} papers (total: {total_harvested})")
                offset += 100

                if total_harvested >= MAX_PAPERS:
                    logger.info(f"Reached MAX_PAPERS limit ({MAX_PAPERS})")
                    break

            except Exception as e:
                logger.error(f"Error harvesting query {query_idx + 1} at offset {offset}: {e}")
                break

        if total_harvested >= MAX_PAPERS:
            break

    df = pd.DataFrame(all_papers)

    # Save raw harvest
    output_path = f'{BASE_PATH}/data/outputs/papers_raw.csv'
    df.to_csv(output_path, index=False, encoding='utf-8')
    logger.info(f"Saved {len(df)} raw papers to {output_path}")

    return df

print("Harvest functions defined")
# Out:
# Harvest functions defined

# %%
@retry(
    stop=stop_after_attempt(MAX_RETRIES),
    wait=wait_exponential(multiplier=1, max=60),
    retry=retry_if_exception_type((requests.exceptions.RequestException,))
)
def unpaywall_lookup(doi: str) -> dict:
    """Lookup paper in Unpaywall API"""
    if not doi:
        return {}

    url = f"{UNPAYWALL_URL}{doi}"
    params = {'email': UNPAYWALL_EMAIL}

    try:
        response = requests.get(url, params=params, headers=HEADERS, timeout=20)

        if response.status_code == 404:
            return {}

        response.raise_for_status()
        time.sleep(UNPAYWALL_SLEEP)

        return response.json()
    except requests.exceptions.HTTPError as e:
        if e.response.status_code == 404:
            return {}
        raise


def attach_pdf_links(df: pd.DataFrame) -> pd.DataFrame:
    """Attach PDF URLs from Unpaywall to dataframe"""
    logger.info(f"Fetching PDF links for {len(df)} papers")

    pdf_urls = []
    oa_statuses = []
    unpaywall_jsons = []

    for idx, row in tqdm(df.iterrows(), total=len(df), desc="Unpaywall lookups"):
        doi_norm = row.get('doi_norm')

        if pd.isna(doi_norm):
            pdf_urls.append(None)
            oa_statuses.append('none')
            unpaywall_jsons.append(None)
            continue

        try:
            result = unpaywall_lookup(doi_norm)

            if not result:
                pdf_urls.append(None)
                oa_statuses.append('none')
                unpaywall_jsons.append(None)
                continue

            # Extract PDF URL
            pdf_url = None
            oa_status = 'closed'

            if result.get('is_oa'):
                best_oa = result.get('best_oa_location')
                if best_oa:
                    pdf_url = best_oa.get('url_for_pdf') or best_oa.get('url')
                    oa_status = best_oa.get('version', 'green')

            pdf_urls.append(pdf_url)
            oa_statuses.append(oa_status)
            unpaywall_jsons.append(json.dumps(result))

        except Exception as e:
            logger.error(f"Error fetching Unpaywall for DOI {doi_norm}: {e}")
            pdf_urls.append(None)
            oa_statuses.append('error')
            unpaywall_jsons.append(None)

    df['pdf_url'] = pdf_urls
    df['oa_status'] = oa_statuses
    df['unpaywall_json'] = unpaywall_jsons

    # Save papers_master.csv
    output_path = f'{BASE_PATH}/data/outputs/papers_master.csv'
    df.to_csv(output_path, index=False, encoding='utf-8')
    logger.info(f"Saved papers_master.csv with {len(df)} rows")

    return df

print("Unpaywall functions defined")
# Out:
# Unpaywall functions defined

# %%
@retry(
    stop=stop_after_attempt(3),
    wait=wait_exponential(multiplier=1, max=30),
    retry=retry_if_exception_type((requests.exceptions.RequestException,))
)
def extract_email_from_html(url: str) -> Tuple[Optional[str], Optional[str]]:
    """Extract corresponding author email from HTML page"""
    if not url:
        return None, None

    try:
        response = requests.get(url, headers=HEADERS, timeout=20)
        response.raise_for_status()

        soup = BeautifulSoup(response.text, 'lxml')
        text = soup.get_text(" ", strip=True)

        # Find all emails
        emails = EMAIL_RE.findall(text)

        if not emails:
            time.sleep(HTML_REQUEST_SLEEP)
            return None, None

        # Check for emails near correspondence keywords
        for email in emails:
            email_pos = text.find(email)
            snippet_start = max(0, email_pos - 200)
            snippet_end = min(len(text), email_pos + 200)
            snippet = text[snippet_start:snippet_end]

            if CORR_KEYWORDS_RE.search(snippet):
                time.sleep(HTML_REQUEST_SLEEP)
                return email, snippet

        # Return first email if no correspondence keyword found
        first_email = emails[0]
        email_pos = text.find(first_email)
        snippet_start = max(0, email_pos - 200)
        snippet_end = min(len(text), email_pos + 200)
        snippet = text[snippet_start:snippet_end]

        time.sleep(HTML_REQUEST_SLEEP)
        return first_email, snippet

    except Exception as e:
        logger.error(f"Error extracting email from HTML {url}: {e}")
        time.sleep(HTML_REQUEST_SLEEP)
        return None, None


def extract_email_from_pdf(pdf_url: str, max_bytes: int = 200_000) -> Tuple[Optional[str], Optional[str]]:
    """Extract corresponding author email from PDF"""
    if not pdf_url or not PDFMINER_AVAILABLE:
        return None, None

    try:
        # Download PDF with size limit
        response = requests.get(pdf_url, headers=HEADERS, timeout=30, stream=True)
        response.raise_for_status()

        pdf_content = BytesIO()
        downloaded = 0

        for chunk in response.iter_content(chunk_size=8192):
            if downloaded >= max_bytes:
                break
            pdf_content.write(chunk)
            downloaded += len(chunk)

        pdf_content.seek(0)

        # Extract text from PDF using simpler method
        try:
            # Try high-level API first (newer pdfminer.six)
            from pdfminer.high_level import extract_text
            text = extract_text(pdf_content)
        except ImportError:
            # Fallback to lower-level API (older pdfminer.six)
            from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
            from pdfminer.converter import TextConverter
            from pdfminer.layout import LAParams
            from pdfminer.pdfpage import PDFPage

            output = StringIO()
            manager = PDFResourceManager()
            converter = TextConverter(manager, output, laparams=LAParams())
            interpreter = PDFPageInterpreter(manager, converter)

            for page in PDFPage.get_pages(pdf_content, maxpages=4):  # First 4 pages only
                interpreter.process_page(page)

            converter.close()
            text = output.getvalue()
            output.close()

        # Find emails
        emails = EMAIL_RE.findall(text)

        if not emails:
            time.sleep(PDF_REQUEST_SLEEP)
            return None, None

        # Check for emails near correspondence keywords
        for email in emails:
            email_pos = text.find(email)
            snippet_start = max(0, email_pos - 200)
            snippet_end = min(len(text), email_pos + 200)
            snippet = text[snippet_start:snippet_end]

            if CORR_KEYWORDS_RE.search(snippet):
                time.sleep(PDF_REQUEST_SLEEP)
                return email, snippet

        # Return first email
        first_email = emails[0]
        email_pos = text.find(first_email)
        snippet_start = max(0, email_pos - 200)
        snippet_end = min(len(text), email_pos + 200)
        snippet = text[snippet_start:snippet_end]

        time.sleep(PDF_REQUEST_SLEEP)
        return first_email, snippet

    except Exception as e:
        logger.error(f"Error extracting email from PDF {pdf_url}: {e}")
        time.sleep(PDF_REQUEST_SLEEP)
        return None, None

def extract_affiliation_from_snippet(snippet: str) -> Optional[str]:
    """Extract affiliation string from text snippet"""
    if not snippet:
        return None

    snippet_lower = snippet.lower()

    # Look for affiliation keywords
    for keyword in AFFILIATION_KEYWORDS:
        if keyword in snippet_lower:
            # Extract surrounding context (up to 150 chars)
            pos = snippet_lower.find(keyword)
            start = max(0, pos - 75)
            end = min(len(snippet), pos + 75)
            return snippet[start:end].strip()

    return None


def find_corresponding_author(row: pd.Series) -> dict:
    """Find corresponding author for a paper"""
    result = {
        'paper_id': row.get('ss_paper_id'),
        'doi_norm': row.get('doi_norm'),
        'title': row.get('title'),
        'contact_email': None,
        'contact_source': 'none',
        'affiliation_snippet': None,
        'candidate_author_name': None,
        'candidate_author_affiliation_raw': None,
        'extraction_timestamp': datetime.utcnow().isoformat(),
        'extraction_notes': []
    }

    # Try HTML first
    if pd.notna(row.get('url')):
        try:
            email, snippet = extract_email_from_html(row['url'])
            if email:
                result['contact_email'] = email
                result['contact_source'] = 'publisher_html'
                result['affiliation_snippet'] = snippet
                result['candidate_author_affiliation_raw'] = extract_affiliation_from_snippet(snippet)
                result['extraction_notes'].append('Found in publisher HTML')
                result['extraction_notes'] = '; '.join(result['extraction_notes'])
                return result
            else:
                result['extraction_notes'].append('No email in HTML')
        except Exception as e:
            result['extraction_notes'].append(f'HTML extraction error: {str(e)[:100]}')

    # Try PDF
    if pd.notna(row.get('pdf_url')):
        try:
            email, snippet = extract_email_from_pdf(row['pdf_url'])
            if email:
                result['contact_email'] = email
                result['contact_source'] = 'pdf'
                result['affiliation_snippet'] = snippet
                result['candidate_author_affiliation_raw'] = extract_affiliation_from_snippet(snippet)
                result['extraction_notes'].append('Found in PDF')
                result['extraction_notes'] = '; '.join(result['extraction_notes'])
                return result
            else:
                result['extraction_notes'].append('No email in PDF')
        except Exception as e:
            result['extraction_notes'].append(f'PDF extraction error: {str(e)[:100]}')

    # Try to get last author as candidate
    try:
        authors = json.loads(row.get('authors', '[]'))
        if authors:
            last_author = authors[-1]
            result['candidate_author_name'] = last_author.get('name')
            result['extraction_notes'].append('Last author recorded as candidate')
    except:
        pass

    result['extraction_notes'] = '; '.join(result['extraction_notes'])
    return result


def bulk_find_corresponding_authors(df: pd.DataFrame) -> pd.DataFrame:
    """Bulk extract corresponding authors"""
    logger.info(f"Extracting corresponding authors for {len(df)} papers")

    results = []

    for idx, row in tqdm(df.iterrows(), total=len(df), desc="Extracting authors"):
        result = find_corresponding_author(row)
        result['harvest_provenance'] = f"row_{idx}"
        results.append(result)

        # Checkpoint every 100 papers
        if (idx + 1) % 100 == 0:
            temp_df = pd.DataFrame(results)
            temp_df.to_csv(f'{BASE_PATH}/data/outputs/authors_candidates_temp.csv', index=False, encoding='utf-8')
            logger.info(f"Checkpoint: processed {idx + 1} papers")

    results_df = pd.DataFrame(results)
    return results_df

print("Extraction functions defined")
# Out:
# Extraction functions defined

# %%
def classify_affiliation_string(aff_str: Optional[str]) -> str:
    """Classify affiliation as Academic, Industry, or Unknown"""
    if not aff_str or aff_str.strip() == '':
        return "Unknown"

    aff_lower = aff_str.lower()

    # Check for industry keywords first
    for keyword in INDUSTRY_KEYWORDS:
        if keyword in aff_lower:
            return "Industry"

    # Check for academic keywords
    for keyword in ACADEMIC_KEYWORDS:
        if keyword in aff_lower:
            return "Academic"

    # Check for academic email domains
    if re.search(r'\.edu(?:\.|$)|\.ac\.|\.edu\.', aff_lower):
        return "Academic"

    return "Unknown"


def affiliation_decision_rules(row: dict) -> dict:
    """Apply filtering rules based on affiliation type"""
    aff_type = classify_affiliation_string(row.get('candidate_author_affiliation_raw'))

    row['affiliation_type'] = aff_type

    if aff_type == 'Industry':
        row['keep_candidate'] = False
        row['drop_reason'] = 'Industry affiliation'
    elif aff_type == 'Unknown':
        row['keep_candidate'] = False
        row['drop_reason'] = 'Unknown affiliation'
    elif aff_type == 'Academic':
        row['keep_candidate'] = True
        row['drop_reason'] = ''
    else:
        row['keep_candidate'] = False
        row['drop_reason'] = 'Unclassified'

    return row

print("Classification functions defined")
# Out:
# Classification functions defined

# %%
print("="*80)
print("STARTING PAPER HARVESTING PIPELINE")
print("="*80)

# Step 1: Harvest papers
print("\n[1/5] Harvesting papers from Semantic Scholar...")
df_raw = harvest_all_crossref(QUERIES)
if df_raw.empty:
    raise RuntimeError("Semantic Scholar harvest returned 0 papers — aborting pipeline")
print(f"✅ Harvested {len(df_raw)} raw papers")

# Step 2: Deduplicate and filter by year
print("\n[2/5] Deduplicating and filtering by year...")
df_deduped = dedupe_and_filter_year(df_raw, year=TARGET_YEAR)
print(f"✅ {len(df_deduped)} papers after deduplication")

# Step 3: Attach PDF links from Unpaywall
print("\n[3/5] Fetching PDF links from Unpaywall...")
df_master = attach_pdf_links(df_deduped)
pdf_count = df_master['pdf_url'].notna().sum()
print(f"✅ Found PDF links for {pdf_count}/{len(df_master)} papers")

# Step 4: Extract corresponding authors
print("\n[4/5] Extracting corresponding author emails...")
df_authors = bulk_find_corresponding_authors(df_master)
print(f"✅ Processed {len(df_authors)} papers for author extraction")

# Step 5: Classify and filter
print("\n[5/5] Classifying affiliations...")
authors_classified = df_authors.apply(lambda row: pd.Series(affiliation_decision_rules(row.to_dict())), axis=1)

# Save final authors_candidates.csv
output_path = f'{BASE_PATH}/data/outputs/authors_candidates.csv'
authors_classified.to_csv(output_path, index=False, encoding='utf-8')
print(f"✅ Saved {len(authors_classified)} candidates to authors_candidates.csv")

# Save checkpoint marker
with open(f'{BASE_PATH}/data/outputs/.last_harvest_index', 'w') as f:
    f.write(str(len(df_master)))

print("\n" + "="*80)
print("PIPELINE COMPLETE")
print("="*80)
# Out:
# ================================================================================
# STARTING PAPER HARVESTING PIPELINE
# ================================================================================
#
# [1/5] Harvesting papers from Semantic Scholar...
# /tmp/ipython-input-3534945162.py:114: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   timestamp = datetime.utcnow().isoformat()
# ✅ Harvested 2000 raw papers
#
# [2/5] Deduplicating and filtering by year...
# ✅ 1949 papers after deduplication
#
# [3/5] Fetching PDF links from Unpaywall...
# Unpaywall lookups:   0%|          | 0/1949 [00:00<?, ?it/s]
# ✅ Found PDF links for 1120/1949 papers
#
# [4/5] Extracting corresponding author emails...
# Extracting authors:   0%|          | 0/1949 [00:00<?, ?it/s]
# /tmp/ipython-input-1883406301.py:160: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   'extraction_timestamp': datetime.utcnow().isoformat(),
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.2139/ssrn.5417893: 403 Client Error: Forbidden for url: https://papers.ssrn.com/sol3/papers.cfm?abstract_id=5417893
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1039/d4tb02102a/v2/decision1: Failed to parse: 'www.webofknowledge.comundefinednull&referrer=target%3dhttps%253a%252f%252fwww.webofscience.com%252fwos%253fisproductcode%253dyes%2526init%253dyes%2526destparams%253d%25252fwos%25252fwoscc%25252ffull-record%25252f10.1039%2525252fd4tb02102a%25253ftype%25253ddoi%2526destapp%253dwosfv%2526func%253dframe%2526srcapp%253dpublons%2526type%253ddoi%2526sid%253dusw2ec0d07que50arnkczaaqfpabd%26sid%3dusw2ec0d07que50arnkczaaqfpabd%26detectsessioncomplete%3dtrue', label empty or too long
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1002/1878-0261.70141/v1/decision1: Failed to parse: 'www.webofknowledge.comundefinednull&referrer=target%3dhttps%253a%252f%252fwww.webofscience.com%252fwos%253fisproductcode%253dyes%2526init%253dyes%2526destparams%253d%25252fwos%25252fwoscc%25252ffull-record%25252f10.1002%2525252f1878-0261.70141%25253ftype%25253ddoi%2526destapp%253dwosfv%2526func%253dframe%2526srcapp%253dpublons%2526type%253ddoi%2526sid%253dusw2ec0d73ne2stxa7ydpvdb9merd%26sid%3dusw2ec0d73ne2stxa7ydpvdb9merd%26detectsessioncomplete%3dtrue', label empty or too long
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1101/2025.07.28.667061: 403 Client Error: Forbidden for url: https://www.biorxiv.org/lookup/doi/10.1101/2025.07.28.667061
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.2139/ssrn.5527203: 403 Client Error: Forbidden for url: https://papers.ssrn.com/sol3/papers.cfm?abstract_id=5527203
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.2139/ssrn.5165300: 403 Client Error: Forbidden for url: https://papers.ssrn.com/sol3/papers.cfm?abstract_id=5165300
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.2139/ssrn.5382107: 403 Client Error: Forbidden for url: https://papers.ssrn.com/sol3/papers.cfm?abstract_id=5382107
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.3390/engproc2025087007: 403 Client Error: Forbidden for url: https://www.mdpi.com/2673-4591/87/1/7
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.3390/smartcities8040126: 403 Client Error: Forbidden for url: https://www.mdpi.com/2624-6511/8/4/126
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1158/2159-8290.cd-rw2025-100: 403 Client Error: Forbidden for url: https://aacrjournals.org/cancerdiscovery/article/16/1/OF1/771342/Genotoxic-Stress-Determines-Cell-Fate-Decision-of
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1101/2025.11.13.688391: 403 Client Error: Forbidden for url: https://www.biorxiv.org/lookup/doi/10.1101/2025.11.13.688391
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1101/2025.01.31.635963: 403 Client Error: Forbidden for url: https://www.biorxiv.org/lookup/doi/10.1101/2025.01.31.635963
# /tmp/ipython-input-1883406301.py:15: XMLParsedAsHTMLWarning: It looks like you're using an HTML parser to parse an XML document.
#
# Assuming this really is an XML document, what you're doing might work, but you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the Python package 'lxml' installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#
# If you want or need to use an HTML parser on this document, you can make this warning go away by filtering it. To do that, run this code before calling the BeautifulSoup constructor:
#
#     from bs4 import XMLParsedAsHTMLWarning
#     import warnings
#
#     warnings.filterwarnings("ignore", category=XMLParsedAsHTMLWarning)
#
#   soup = BeautifulSoup(response.text, 'lxml')
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1089/cell.2025.0013: 403 Client Error: Forbidden for url: https://www.liebertpub.com/doi/10.1089/cell.2025.0013
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.35760/eb.2025.v30i1.11870: HTTPSConnectionPool(host='ejournal.gunadarma.ac.id', port=443): Max retries exceeded with url: /index.php/ekbis/article/view/11870 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7a3c057c2ea0>: Failed to establish a new connection: [Errno 113] No route to host'))
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.3390/sym17020161: 403 Client Error: Forbidden for url: https://www.mdpi.com/2073-8994/17/2/161
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.3390/diagnostics15070807: 403 Client Error: Forbidden for url: https://www.mdpi.com/2075-4418/15/7/807
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1002/1878-0261.70141/v1/review1: 502 Server Error: Bad Gateway for url: https://www.webofknowledge.com?DestApp=WOSNX&SrcApp=PUBLONS&DestParams=%2Fwos%2Fwoscc%2Ffull-record%2F10.1002%252F1878-0261.70141%3Ftype%3Ddoi&&DestFail=https%3A%2F%2Fwww.webofknowledge.com%3FDestApp%3DWOSFV%26SrcApp%3DPUBLONS%26DestParams%3D%252Fwos%252Fwoscc%252Ffull-record%252F10.1002%25252F1878-0261.70141%253Ftype%253Ddoi%26e%3Dn9LOsTOX7fkZQ1Sm2E2gje9%252BF4oa5jHkRQID2O5VqBMPS9rojG0xMLSZaHikP%252B3v
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1093/glycob/cwaf061: 403 Client Error: Forbidden for url: https://academic.oup.com/glycob/article/doi/10.1093/glycob/cwaf061/8315866
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1002/1878-0261.70141/v2/review2: Failed to parse: 'www.webofknowledge.comundefinednull&referrer=target%3dhttps%253a%252f%252fwww.webofscience.com%252fwos%253fisproductcode%253dyes%2526init%253dyes%2526destparams%253d%25252fwos%25252fwoscc%25252ffull-record%25252f10.1002%2525252f1878-0261.70141%25253ftype%25253ddoi%2526destapp%253dwosfv%2526func%253dframe%2526srcapp%253dpublons%2526type%253ddoi%2526sid%253dusw2ec0feed4rau6rzbygfbzyk5cm%26sid%3dusw2ec0feed4rau6rzbygfbzyk5cm%26detectsessioncomplete%3dtrue', label empty or too long
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1530/endoabs.109.p312: 522 Server Error: <none> for url: http://www.endocrine-abstracts.org/ea/0109/ea0109P312
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.2139/ssrn.5175594: 403 Client Error: Forbidden for url: https://papers.ssrn.com/sol3/papers.cfm?abstract_id=5175594
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1101/2025.02.04.636565: 403 Client Error: Forbidden for url: https://www.biorxiv.org/lookup/doi/10.1101/2025.02.04.636565
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.2139/ssrn.5211258: 403 Client Error: Forbidden for url: https://papers.ssrn.com/sol3/papers.cfm?abstract_id=5211258
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1101/2025.11.10.687625: 403 Client Error: Forbidden for url: https://www.biorxiv.org/lookup/doi/10.1101/2025.11.10.687625
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1002/1878-0261.70141/v1/review2: Failed to parse: 'www.webofknowledge.comundefinednull&referrer=target%3dhttps%253a%252f%252fwww.webofscience.com%252fwos%253fisproductcode%253dyes%2526init%253dyes%2526destparams%253d%25252fwos%25252fwoscc%25252ffull-record%25252f10.1002%2525252f1878-0261.70141%25253ftype%25253ddoi%2526destapp%253dwosfv%2526func%253dframe%2526srcapp%253dpublons%2526type%253ddoi%2526sid%253dusw2ec0feev4gd36qugezexg2uytv%26sid%3dusw2ec0feev4gd36qugezexg2uytv%26detectsessioncomplete%3dtrue', label empty or too long
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.4018/ijitsa.385939: 429 Client Error: Too Many Requests for url: https://services.igi-global.com/resolvedoi/resolve.aspx?doi=10.4018/IJITSA.385939
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1002/eji.70076/v3/decision1: Failed to parse: 'www.webofknowledge.comundefinednull&referrer=target%3dhttps%253a%252f%252fwww.webofscience.com%252fwos%253fisproductcode%253dyes%2526init%253dyes%2526destparams%253d%25252fwos%25252fwoscc%25252ffull-record%25252f10.1002%2525252feji.70076%25253ftype%25253ddoi%2526destapp%253dwosfv%2526func%253dframe%2526srcapp%253dpublons%2526type%253ddoi%2526sid%253dusw2ec0b2f6fksj2rpqdkofjevxoa%26sid%3dusw2ec0b2f6fksj2rpqdkofjevxoa%26detectsessioncomplete%3dtrue', label empty or too long
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1063/5.0259373: 403 Client Error: Forbidden for url: https://pubs.aip.org/aip/acp/article-lookup/doi/10.1063/5.0259373
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1101/2025.09.17.676780: 403 Client Error: Forbidden for url: https://www.biorxiv.org/lookup/doi/10.1101/2025.09.17.676780
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1177/18724981251389504: 403 Client Error: Forbidden for url: https://journals.sagepub.com/doi/10.1177/18724981251389504
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.3791/31132: 403 Client Error: Forbidden for url: https://app.jove.com/t/31132/cell-fate-reprogramming-of-nematode-germ-cells-into-neurons
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1146/annurev-biodatasci-101424-121439: 403 Client Error: Forbidden for url: https://www.annualreviews.org/content/journals/10.1146/annurev-biodatasci-101424-121439
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1101/2025.05.30.657125: 403 Client Error: Forbidden for url: https://www.biorxiv.org/lookup/doi/10.1101/2025.05.30.657125
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.22541/au.175735334.45794622/v1: 403 Client Error: Forbidden for url: https://www.authorea.com/users/963856/articles/1332580-deciphering-cell-fate-trajectories-using-spatiotemporal-single-cell-transcriptomic-data?commit=8687b04595e748b3fd0db07ba5b23333052ec0ac
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.21608/ijt.2025.363661.1086: HTTPSConnectionPool(host='ijt.journals.ekb.eg', port=443): Max retries exceeded with url: /article_443304.html (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7a3c04b8ad80>, 'Connection to ijt.journals.ekb.eg timed out. (connect timeout=20)'))
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1101/2025.04.09.647220: 403 Client Error: Forbidden for url: https://www.biorxiv.org/lookup/doi/10.1101/2025.04.09.647220
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.20944/preprints202510.2310.v1: 403 Client Error: Forbidden for url: https://www.preprints.org/manuscript/202510.2310/v1
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1177/17470218251404415/v1/decision1: 500 Server Error: Internal Server Error for url: https://www.webofknowledge.com?DestApp=WOSFV&SrcApp=PUBLONS&DestParams=%2Fwos%2Fwoscc%2Ffull-record%2F10.1177%252F17470218251404415%3Ftype%3Ddoi&e=n9LOsTOX7fk9%2BdZ%2BjbtiIwOqbYjl%2FUjVfvGjtCRUJ1S5AOkS4Er%2FtchcYFJZBLsw
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.2118/231167-pa: 403 Client Error: Forbidden for url: https://onepetro.org/SJ/article/30/12/7318/792241/A-Long-Short-Term-Memory-Based-Deep-Learning
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1093/gpbjnl/qzaf013: 403 Client Error: Forbidden for url: https://academic.oup.com/gpb/article/doi/10.1093/gpbjnl/qzaf013/8051908
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.2139/ssrn.5396316: 403 Client Error: Forbidden for url: https://papers.ssrn.com/sol3/papers.cfm?abstract_id=5396316
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1101/2025.08.05.668751: 403 Client Error: Forbidden for url: https://www.biorxiv.org/lookup/doi/10.1101/2025.08.05.668751
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.22541/au.175710079.93897849/v1: 403 Client Error: Forbidden for url: https://www.authorea.com/users/963795/articles/1332496-characterization-of-a-regulatory-network-promoting-cell-fate-segregation-in-the-myxococcus-xanthus-biofilm?commit=6272adf4bfa3d8113e6920947feb8e21e6bf27fd
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1177/21524971251366924: 403 Client Error: Forbidden for url: https://www.liebertpub.com/doi/10.1177/21524971251366924
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1093/jimmun/vkaf283.1082: 403 Client Error: Forbidden for url: https://academic.oup.com/jimmunol/article/doi/10.1093/jimmun/vkaf283.1082/8331568
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1182/blood-2025-5022: 403 Client Error: Forbidden for url: https://ashpublications.org/blood/article/146/Supplement%201/5022/549438/The-long-non-coding-RNA-WT1-AS-controls
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.2991/978-94-6463-858-5_228: 502 Server Error: Bad Gateway for url: https://www.atlantis-press.com/doi/10.2991/978-94-6463-858-5_228
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.2139/ssrn.5143283: 403 Client Error: Forbidden for url: https://papers.ssrn.com/sol3/papers.cfm?abstract_id=5143283
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1101/2025.10.02.679951: 403 Client Error: Forbidden for url: https://www.biorxiv.org/lookup/doi/10.1101/2025.10.02.679951
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1101/2025.03.19.644252: 403 Client Error: Forbidden for url: https://www.biorxiv.org/lookup/doi/10.1101/2025.03.19.644252
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1200/po-25-00315: 403 Client Error: Forbidden for url: https://ascopubs.org/doi/10.1200/PO-25-00315
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.12913/22998624/210215: HTTPSConnectionPool(host='www.astrj.com', port=443): Max retries exceeded with url: /Deep-learning-long-short-term-memory-methods-for-instantaneous-fuel-consumption-prediction,210215,0,2.html (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7a3c059e1340>, 'Connection to www.astrj.com timed out. (connect timeout=20)'))
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.21009/jkoma.082.06: HTTPSConnectionPool(host='journal.unj.ac.id', port=443): Max retries exceeded with url: /unj/index.php/jkoma/article/view/64524 (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1010)')))
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1177/18724981241291422: 403 Client Error: Forbidden for url: https://journals.sagepub.com/doi/10.1177/18724981241291422
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1101/2025.04.04.647217: 403 Client Error: Forbidden for url: https://www.biorxiv.org/lookup/doi/10.1101/2025.04.04.647217
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.2139/ssrn.5960272: 403 Client Error: Forbidden for url: https://papers.ssrn.com/sol3/papers.cfm?abstract_id=5960272
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1101/2025.03.19.644244: 403 Client Error: Forbidden for url: https://www.biorxiv.org/lookup/doi/10.1101/2025.03.19.644244
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.4103/ijnpnd.ijnpnd_87_24: 403 Client Error: Forbidden for url: https://journals.lww.com/10.4103/ijnpnd.ijnpnd_87_24
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1177/00368504251331706: 403 Client Error: Forbidden for url: https://journals.sagepub.com/doi/10.1177/00368504251331706
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1158/1538-7445.ovarian25-b064: 403 Client Error: Forbidden for url: https://aacrjournals.org/cancerres/article/85/18_Supplement/B064/765203/Abstract-B064-Ovarian-cancer-induced-ascites-fluid
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1002/aidi.202500042: 403 Client Error: Forbidden for url: https://advanced.onlinelibrary.wiley.com/doi/10.1002/aidi.202500042
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1063/5.0247626: 403 Client Error: Forbidden for url: https://pubs.aip.org/aip/acp/article-lookup/doi/10.1063/5.0247626
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1101/2025.03.19.644201: 403 Client Error: Forbidden for url: https://www.biorxiv.org/lookup/doi/10.1101/2025.03.19.644201
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1002/advs.202409642: 403 Client Error: Forbidden for url: https://advanced.onlinelibrary.wiley.com/doi/10.1002/advs.202409642
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.2174/011574888x355333241203114713: 403 Client Error: Forbidden for url: https://www.eurekaselect.com/237218/article
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.25126/jtiik.2025129445: 403 Client Error: Forbidden for url: https://jtiik.ub.ac.id/index.php/jtiik/article/view/9445
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1061/9780784486184.026: 403 Client Error: Forbidden for url: https://ascelibrary.org/doi/10.1061/9780784486184.026
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.2139/ssrn.5933077: 403 Client Error: Forbidden for url: https://papers.ssrn.com/sol3/papers.cfm?abstract_id=5933077
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.25126/jtiik.20259445: 403 Client Error: Forbidden for url: https://jtiik.ub.ac.id/index.php/jtiik/article/view/9445
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1101/2025.05.22.652867: 403 Client Error: Forbidden for url: https://www.biorxiv.org/lookup/doi/10.1101/2025.05.22.652867
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.2139/ssrn.5947414: 403 Client Error: Forbidden for url: https://papers.ssrn.com/sol3/papers.cfm?abstract_id=5947414
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.2139/ssrn.5293791: 403 Client Error: Forbidden for url: https://papers.ssrn.com/sol3/papers.cfm?abstract_id=5293791
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1101/2025.02.05.636709: 403 Client Error: Forbidden for url: https://www.biorxiv.org/lookup/doi/10.1101/2025.02.05.636709
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.2139/ssrn.5210812: 403 Client Error: Forbidden for url: https://papers.ssrn.com/sol3/papers.cfm?abstract_id=5210812
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1101/2025.07.28.667115: 403 Client Error: Forbidden for url: https://www.biorxiv.org/lookup/doi/10.1101/2025.07.28.667115
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1182/blood-2025-5038: 403 Client Error: Forbidden for url: https://ashpublications.org/blood/article/146/Supplement%201/5038/549422/CELF2-deficient-mutations-promote-B-cell-lymphoma
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1101/2025.06.16.659412: 403 Client Error: Forbidden for url: https://www.biorxiv.org/lookup/doi/10.1101/2025.06.16.659412
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.3390/biomedicines13112783: 403 Client Error: Forbidden for url: https://www.mdpi.com/2227-9059/13/11/2783
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.2118/230427-ms: 403 Client Error: Forbidden for url: https://onepetro.org/SPECTCE/proceedings/25CTC/25CTC/D021S011R001/793977
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.22541/essoar.173991354.46305207/v1: 403 Client Error: Forbidden for url: https://essopenarchive.org/users/839607/articles/1269335-predicting-the-evolution-of-extreme-water-levels-with-long-short-term-memory-station-based-approximated-models-and-transfer-learning-techniques?commit=533003a0aca3cbf6baf8930dee43f584aed112e6
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1101/2025.01.30.635582: 403 Client Error: Forbidden for url: https://www.biorxiv.org/lookup/doi/10.1101/2025.01.30.635582
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.2139/ssrn.5155247: 403 Client Error: Forbidden for url: https://papers.ssrn.com/sol3/papers.cfm?abstract_id=5155247
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.64898/2025.12.09.693267: 403 Client Error: Forbidden for url: https://www.biorxiv.org/lookup/doi/10.64898/2025.12.09.693267
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.22541/au.173901291.14107238/v1: 403 Client Error: Forbidden for url: https://www.authorea.com/users/889726/articles/1267060-benford-s-law-in-basic-rnn-and-long-short-term-memory-lstm-and-their-associations?commit=565932d628382edbfffd415e2f11538676d7e60c
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1101/2025.02.24.639895: 403 Client Error: Forbidden for url: https://www.biorxiv.org/lookup/doi/10.1101/2025.02.24.639895
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1142/s0218126625502949: 403 Client Error: Forbidden for url: https://www.worldscientific.com/doi/10.1142/S0218126625502949
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1101/2025.01.18.630727: 502 Server Error: Bad Gateway for url: http://biorxiv.org/lookup/doi/10.1101/2025.01.18.630727
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1101/2025.01.14.632991: 403 Client Error: Forbidden for url: https://www.biorxiv.org/lookup/doi/10.1101/2025.01.14.632991
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1101/2025.10.09.681513: 403 Client Error: Forbidden for url: https://www.biorxiv.org/lookup/doi/10.1101/2025.10.09.681513
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1080/17583004.2025.2560126: 403 Client Error: Forbidden for url: https://www.tandfonline.com/doi/full/10.1080/17583004.2025.2560126
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1182/blood-2025-967: 403 Client Error: Forbidden for url: https://ashpublications.org/blood/article/146/Supplement%201/967/554579/Trimodal-single-cell-profiling-reveals-principles
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1101/2025.09.24.678191: 403 Client Error: Forbidden for url: https://www.biorxiv.org/lookup/doi/10.1101/2025.09.24.678191
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.2523/iptc-24898-ms: 403 Client Error: Forbidden for url: https://onepetro.org/IPTCONF/proceedings/25IPTC/25IPTC/D022S008R014/641258
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1101/2025.05.30.656945: 403 Client Error: Forbidden for url: https://www.biorxiv.org/lookup/doi/10.1101/2025.05.30.656945
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.36227/techrxiv.173930988.88917796/v1: 403 Client Error: Forbidden for url: https://www.techrxiv.org/users/887712/articles/1265754-dynamic-optimization-of-transportation-networks-in-logistics-using-long-short-term-memory-neural-networks?commit=ce7ae8d71a6fff42b4531f29c571f21d994e6c6a
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.2139/ssrn.5848495: 403 Client Error: Forbidden for url: https://papers.ssrn.com/sol3/papers.cfm?abstract_id=5848495
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.2139/ssrn.5344698: 403 Client Error: Forbidden for url: https://papers.ssrn.com/sol3/papers.cfm?abstract_id=5344698
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1101/2025.09.17.676733: 403 Client Error: Forbidden for url: https://www.biorxiv.org/lookup/doi/10.1101/2025.09.17.676733
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1101/2025.02.02.636151: 403 Client Error: Forbidden for url: https://www.biorxiv.org/lookup/doi/10.1101/2025.02.02.636151
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1093/med/9780192867636.003.0007: 403 Client Error: Forbidden for url: https://academic.oup.com/book/61412/chapter/533825213
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1101/2025.02.04.636331: 403 Client Error: Forbidden for url: https://www.biorxiv.org/lookup/doi/10.1101/2025.02.04.636331
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.36227/techrxiv.174140797.74178003/v1: 403 Client Error: Forbidden for url: https://www.techrxiv.org/users/898620/articles/1274479-cervical-spine-posture-monitoring-using-flex-and-imu-sensors-with-long-short-term-memory-networks?commit=9a2533f2bc311effbdbf788c18dd35088045e4be
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1101/2025.07.02.662808: 403 Client Error: Forbidden for url: https://www.biorxiv.org/lookup/doi/10.1101/2025.07.02.662808
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.2139/ssrn.5547679: 403 Client Error: Forbidden for url: https://papers.ssrn.com/sol3/papers.cfm?abstract_id=5547679
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.2139/ssrn.5221158: 403 Client Error: Forbidden for url: https://papers.ssrn.com/sol3/papers.cfm?abstract_id=5221158
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.2139/ssrn.5211266: 403 Client Error: Forbidden for url: https://papers.ssrn.com/sol3/papers.cfm?abstract_id=5211266
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.3390/ai6090215: 403 Client Error: Forbidden for url: https://www.mdpi.com/2673-2688/6/9/215
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.3390/bioengineering12070760: 403 Client Error: Forbidden for url: https://www.mdpi.com/2306-5354/12/7/760
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1097/jsm.0000000000001369: 403 Client Error: Forbidden for url: https://journals.lww.com/10.1097/JSM.0000000000001369
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1093/jimmun/vkaf283.2221: 403 Client Error: Forbidden for url: https://academic.oup.com/jimmunol/article/doi/10.1093/jimmun/vkaf283.2221/8329833
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.64898/2025.12.24.696351: 403 Client Error: Forbidden for url: https://www.biorxiv.org/lookup/doi/10.64898/2025.12.24.696351
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1002/cbf.70135: 403 Client Error: Forbidden for url: https://analyticalsciencejournals.onlinelibrary.wiley.com/doi/10.1002/cbf.70135
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1089/scd.2025.0062: 403 Client Error: Forbidden for url: https://journals.sagepub.com/doi/10.1089/scd.2025.0062
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.3390/biology14060679: 403 Client Error: Forbidden for url: https://www.mdpi.com/2079-7737/14/6/679
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.17148/ijarcce.2025.14104: 404 Client Error: Not Found for url: https://ijarcce.com/wp-content/uploads/2025/01/IJARCCE.2025.14104.pdf
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.31223/x5db0k: 403 Client Error: Forbidden for url: https://eartharxiv.org/repository/view/7716/
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1111/cpr.70088: 403 Client Error: Forbidden for url: https://onlinelibrary.wiley.com/doi/10.1111/cpr.70088
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.25126/jtiik.2025129444: 403 Client Error: Forbidden for url: https://jtiik.ub.ac.id/index.php/jtiik/article/view/9444
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.31328/js.v8i1.7089: 403 Client Error: Forbidden for url: https://publishing-widyagama.ac.id/ejournal-v2/index.php/js/article/view/7089
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1101/2025.04.03.647013: 403 Client Error: Forbidden for url: https://www.biorxiv.org/lookup/doi/10.1101/2025.04.03.647013
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1101/2025.10.28.685172: 403 Client Error: Forbidden for url: https://www.biorxiv.org/lookup/doi/10.1101/2025.10.28.685172
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1093/jimmun/vkaf283.581: 403 Client Error: Forbidden for url: https://academic.oup.com/jimmunol/article/doi/10.1093/jimmun/vkaf283.581/8330431
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1101/2025.06.09.658583: 403 Client Error: Forbidden for url: https://www.biorxiv.org/lookup/doi/10.1101/2025.06.09.658583
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.25126/jtiik.1229444: 403 Client Error: Forbidden for url: https://jtiik.ub.ac.id/index.php/jtiik/article/view/9444
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.2139/ssrn.5325148: 403 Client Error: Forbidden for url: https://papers.ssrn.com/sol3/papers.cfm?abstract_id=5325148
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1101/2025.05.12.653464: 403 Client Error: Forbidden for url: https://www.biorxiv.org/lookup/doi/10.1101/2025.05.12.653464
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.7249/pea3409-1: 403 Client Error: Forbidden for url: https://www.rand.org/pubs/perspectives/PEA3409-1.html
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.34010/komputika.v14i1.14914: 403 Client Error: Forbidden for url: https://ojs.unikom.ac.id/index.php/komputika/article/view/14914
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1101/2025.05.27.656406: 403 Client Error: Forbidden for url: https://www.biorxiv.org/lookup/doi/10.1101/2025.05.27.656406
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.2139/ssrn.5240852: 403 Client Error: Forbidden for url: https://papers.ssrn.com/sol3/papers.cfm?abstract_id=5240852
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1101/2025.06.05.658111: 403 Client Error: Forbidden for url: https://www.biorxiv.org/lookup/doi/10.1101/2025.06.05.658111
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1093/jimmun/vkaf283.1956: 403 Client Error: Forbidden for url: https://academic.oup.com/jimmunol/article/doi/10.1093/jimmun/vkaf283.1956/8330106
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1101/2025.11.04.686522: 403 Client Error: Forbidden for url: https://www.biorxiv.org/lookup/doi/10.1101/2025.11.04.686522
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.34133/research.1061: 403 Client Error: Forbidden for url: https://spj.science.org/doi/10.34133/research.1061
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1101/2025.09.01.673503: 403 Client Error: Forbidden for url: https://www.biorxiv.org/lookup/doi/10.1101/2025.09.01.673503
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1145/3765612.3767812: 403 Client Error: Forbidden for url: https://dl.acm.org/doi/10.1145/3765612.3767812
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.2139/ssrn.5344847: 403 Client Error: Forbidden for url: https://papers.ssrn.com/sol3/papers.cfm?abstract_id=5344847
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.2139/ssrn.5347435: 403 Client Error: Forbidden for url: https://papers.ssrn.com/sol3/papers.cfm?abstract_id=5347435
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1145/3711896.3737000: 403 Client Error: Forbidden for url: https://dl.acm.org/doi/10.1145/3711896.3737000
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.2139/ssrn.5162878: 403 Client Error: Forbidden for url: https://papers.ssrn.com/sol3/papers.cfm?abstract_id=5162878
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.2139/ssrn.5782857: 403 Client Error: Forbidden for url: https://papers.ssrn.com/sol3/papers.cfm?abstract_id=5782857
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1126/sciadv.adt1971: 403 Client Error: Forbidden for url: https://www.science.org/doi/10.1126/sciadv.adt1971
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1101/2025.09.11.675740: 403 Client Error: Forbidden for url: https://www.biorxiv.org/lookup/doi/10.1101/2025.09.11.675740
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1101/2025.05.19.654885: 403 Client Error: Forbidden for url: https://www.biorxiv.org/lookup/doi/10.1101/2025.05.19.654885
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1142/s0218126625503633: 403 Client Error: Forbidden for url: https://www.worldscientific.com/doi/10.1142/S0218126625503633
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.2139/ssrn.5643248: 403 Client Error: Forbidden for url: https://papers.ssrn.com/sol3/papers.cfm?abstract_id=5643248
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1101/2025.06.04.657585: 403 Client Error: Forbidden for url: https://www.biorxiv.org/lookup/doi/10.1101/2025.06.04.657585
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.2139/ssrn.5586582: 403 Client Error: Forbidden for url: https://papers.ssrn.com/sol3/papers.cfm?abstract_id=5586582
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.20944/preprints202509.1273.v1: 403 Client Error: Forbidden for url: https://www.preprints.org/manuscript/202509.1273/v1
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1002/9781394372409.ch2: 403 Client Error: Forbidden for url: https://onlinelibrary.wiley.com/doi/10.1002/9781394372409.ch2
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1101/2025.09.01.672695: 403 Client Error: Forbidden for url: https://www.biorxiv.org/lookup/doi/10.1101/2025.09.01.672695
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1111/pce.15459: 403 Client Error: Forbidden for url: https://onlinelibrary.wiley.com/doi/10.1111/pce.15459
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.22541/au.174405211.12366502/v1: 403 Client Error: Forbidden for url: https://www.authorea.com/users/809484/articles/1283660-long-short-term-memory-model-to-forecast-river-ice-breakup-throughout-alaska-usa?commit=ee4dbd8afa521cccac82aab46b0bb419cf6abf27
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1103/63d2-4wq6: 403 Client Error: Forbidden for url: https://link.aps.org/doi/10.1103/63d2-4wq6
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.2139/ssrn.5354598: 403 Client Error: Forbidden for url: https://papers.ssrn.com/sol3/papers.cfm?abstract_id=5354598
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1242/dev.204754: 403 Client Error: Forbidden for url: https://journals.biologists.com/dev/article/152/6/dev204754/367519/Correction-Vascular-endothelial-growth-factor-c
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1101/2025.10.22.683900: 403 Client Error: Forbidden for url: https://www.biorxiv.org/lookup/doi/10.1101/2025.10.22.683900
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.64898/2025.12.27.696651: 403 Client Error: Forbidden for url: https://www.biorxiv.org/lookup/doi/10.64898/2025.12.27.696651
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1126/sciadv.aee1296: 403 Client Error: Forbidden for url: https://www.science.org/doi/10.1126/sciadv.aee1296
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1093/jge/gxaf114: 403 Client Error: Forbidden for url: https://academic.oup.com/jge/article/22/6/1876/8254140
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1101/2025.07.01.661069: 403 Client Error: Forbidden for url: https://www.biorxiv.org/lookup/doi/10.1101/2025.07.01.661069
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.2139/ssrn.5910402: 403 Client Error: Forbidden for url: https://papers.ssrn.com/sol3/papers.cfm?abstract_id=5910402
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1101/2025.02.18.638163: 403 Client Error: Forbidden for url: https://www.biorxiv.org/lookup/doi/10.1101/2025.02.18.638163
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1145/3768322.3769018: 403 Client Error: Forbidden for url: https://dl.acm.org/doi/10.1145/3768322.3769018
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1108/mlag-08-2024-0007: 403 Client Error: Forbidden for url: https://www.emerald.com/mlag/article/1/1/60/1254984/Predicting-soil-stress-strain-behaviour-with
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.63386/617603: 404 Client Error: Not Found for url: https://zkg-bauverlag-de.com/2025/05/13/a-data-driven-approach-for-predicting-shallow-foundation-settlement-using-long-short-term-memory-networks/
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.20944/preprints202508.0647.v1: 403 Client Error: Forbidden for url: https://www.preprints.org/manuscript/202508.0647/v1
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.3390/toxics13050327: 403 Client Error: Forbidden for url: https://www.mdpi.com/2305-6304/13/5/327
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1002/1878-0261.70141: 403 Client Error: Forbidden for url: https://febs.onlinelibrary.wiley.com/doi/10.1002/1878-0261.70141
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.2139/ssrn.5138017: 403 Client Error: Forbidden for url: https://papers.ssrn.com/sol3/papers.cfm?abstract_id=5138017
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1101/2025.11.10.687565: 403 Client Error: Forbidden for url: https://www.biorxiv.org/lookup/doi/10.1101/2025.11.10.687565
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.2139/ssrn.5137273: 403 Client Error: Forbidden for url: https://papers.ssrn.com/sol3/papers.cfm?abstract_id=5137273
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.2139/ssrn.5405487: 403 Client Error: Forbidden for url: https://papers.ssrn.com/sol3/papers.cfm?abstract_id=5405487
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.2139/ssrn.5127473: 403 Client Error: Forbidden for url: https://papers.ssrn.com/sol3/papers.cfm?abstract_id=5127473
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.2139/ssrn.5228319: 403 Client Error: Forbidden for url: https://papers.ssrn.com/sol3/papers.cfm?abstract_id=5228319
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1101/2025.05.13.653630: 403 Client Error: Forbidden for url: https://www.biorxiv.org/lookup/doi/10.1101/2025.05.13.653630
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.3390/ijms26104911: 403 Client Error: Forbidden for url: https://www.mdpi.com/1422-0067/26/10/4911
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1142/9789819814695_0014: 403 Client Error: Forbidden for url: https://www.worldscientific.com/doi/10.1142/9789819814695_0014
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1182/blood-2025-4777: 403 Client Error: Forbidden for url: https://ashpublications.org/blood/article/146/Supplement%201/4777/552858/Divergent-exhaustion-networks-define-memory-CD8-T
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1002/ente.202500943: 403 Client Error: Forbidden for url: https://onlinelibrary.wiley.com/doi/10.1002/ente.202500943
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1101/2025.06.06.655355: 403 Client Error: Forbidden for url: https://www.biorxiv.org/lookup/doi/10.1101/2025.06.06.655355
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1101/2025.09.29.679324: 403 Client Error: Forbidden for url: https://www.biorxiv.org/lookup/doi/10.1101/2025.09.29.679324
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1101/2025.08.13.670223: 403 Client Error: Forbidden for url: https://www.biorxiv.org/lookup/doi/10.1101/2025.08.13.670223
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1111/ppl.70294: 403 Client Error: Forbidden for url: https://onlinelibrary.wiley.com/doi/10.1111/ppl.70294
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1101/2025.08.02.668269: 403 Client Error: Forbidden for url: https://www.biorxiv.org/lookup/doi/10.1101/2025.08.02.668269
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.2139/ssrn.5173613: 403 Client Error: Forbidden for url: https://papers.ssrn.com/sol3/papers.cfm?abstract_id=5173613
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1158/1538-7445.am2025-7500: 403 Client Error: Forbidden for url: https://aacrjournals.org/cancerres/article/85/8_Supplement_1/7500/760544/Abstract-7500-Joint-reconstruction-of-single-cell
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.2139/ssrn.5133415: 403 Client Error: Forbidden for url: https://papers.ssrn.com/sol3/papers.cfm?abstract_id=5133415
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.2139/ssrn.5159594: 403 Client Error: Forbidden for url: https://papers.ssrn.com/sol3/papers.cfm?abstract_id=5159594
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.63386/617743: 404 Client Error: Not Found for url: https://zkg-bauverlag-de.com/2025/05/22/hybrid-time-series-forecasting-with-limited-data-combining-deep-learning-and-traditional-models-for-short-and-long-term-prediction/
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1177/02611929251372009: 403 Client Error: Forbidden for url: https://journals.sagepub.com/doi/10.1177/02611929251372009
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.2139/ssrn.5959116: 403 Client Error: Forbidden for url: https://papers.ssrn.com/sol3/papers.cfm?abstract_id=5959116
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1371/journal.pone.0316666: HTTPSConnectionPool(host='dx.plos.org', port=443): Read timed out. (read timeout=20)
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1142/s0218126626500192: 403 Client Error: Forbidden for url: https://www.worldscientific.com/doi/10.1142/S0218126626500192
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.2139/ssrn.5243068: 403 Client Error: Forbidden for url: https://papers.ssrn.com/sol3/papers.cfm?abstract_id=5243068
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.2139/ssrn.5217129: 403 Client Error: Forbidden for url: https://papers.ssrn.com/sol3/papers.cfm?abstract_id=5217129
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.3390/en18030543: 403 Client Error: Forbidden for url: https://www.mdpi.com/1996-1073/18/3/543
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.2139/ssrn.5358510: 403 Client Error: Forbidden for url: https://papers.ssrn.com/sol3/papers.cfm?abstract_id=5358510
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1002/we.70025/v2/review2: Failed to parse: 'www.webofknowledge.comundefinednull&referrer=target%3dhttps%253a%252f%252fwww.webofscience.com%252fwos%253fisproductcode%253dyes%2526init%253dyes%2526destparams%253d%25252fwos%25252fwoscc%25252ffull-record%25252f10.1002%2525252fwe.70025%25253ftype%25253ddoi%2526destapp%253dwosfv%2526func%253dframe%2526srcapp%253dpublons%2526type%253ddoi%2526sid%253dusw2ec0fe2nmz765cyrs2vqhdwvhp%26sid%3dusw2ec0fe2nmz765cyrs2vqhdwvhp%26detectsessioncomplete%3dtrue', label empty or too long
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1111/boc.70032: 403 Client Error: Forbidden for url: https://onlinelibrary.wiley.com/doi/10.1111/boc.70032
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.4018/979-8-3693-7260-9.ch014: 429 Client Error: Too Many Requests for url: https://services.igi-global.com/resolvedoi/resolve.aspx?doi=10.4018/979-8-3693-7260-9.ch014
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1089/cell.2025.0007: 403 Client Error: Forbidden for url: https://www.liebertpub.com/doi/10.1089/cell.2025.0007
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.2139/ssrn.5137810: 403 Client Error: Forbidden for url: https://papers.ssrn.com/sol3/papers.cfm?abstract_id=5137810
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.20944/preprints202507.2047.v1: 403 Client Error: Forbidden for url: https://www.preprints.org/manuscript/202507.2047/v1
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.2139/ssrn.5370862: 403 Client Error: Forbidden for url: https://papers.ssrn.com/sol3/papers.cfm?abstract_id=5370862
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.2139/ssrn.5890543: 403 Client Error: Forbidden for url: https://papers.ssrn.com/sol3/papers.cfm?abstract_id=5890543
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.20944/preprints202503.0886.v1: 403 Client Error: Forbidden for url: https://www.preprints.org/manuscript/202503.0886/v1
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.2139/ssrn.5137808: 403 Client Error: Forbidden for url: https://papers.ssrn.com/sol3/papers.cfm?abstract_id=5137808
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.2139/ssrn.5680082: 403 Client Error: Forbidden for url: https://papers.ssrn.com/sol3/papers.cfm?abstract_id=5680082
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.2139/ssrn.5332359: 403 Client Error: Forbidden for url: https://papers.ssrn.com/sol3/papers.cfm?abstract_id=5332359
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.2118/226202-pa: 403 Client Error: Forbidden for url: https://onepetro.org/SJ/article/30/06/3260/653933/Long-Term-Reservoir-Fluid-Production-Forecasting
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.2118/pw0562: 403 Client Error: Forbidden for url: https://onepetro.org/spe/general-information/1780/Long-term-verses-short-term-production-forecast
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1002/ente.202500914: 403 Client Error: Forbidden for url: https://onlinelibrary.wiley.com/doi/10.1002/ente.202500914
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1002/cbf.70119: 403 Client Error: Forbidden for url: https://analyticalsciencejournals.onlinelibrary.wiley.com/doi/10.1002/cbf.70119
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1029/2025jh000768: 403 Client Error: Forbidden for url: https://agupubs.onlinelibrary.wiley.com/doi/10.1029/2025JH000768
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.2139/ssrn.5082353: 403 Client Error: Forbidden for url: https://papers.ssrn.com/sol3/papers.cfm?abstract_id=5082353
# ...
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1158/1535-7163.targ-25-c031: 403 Client Error: Forbidden for url: https://aacrjournals.org/mct/article/24/10_Supplement/C031/766483/Abstract-C031-Disarming-colorectal-plasticity-Dual
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1101/2025.01.24.634773: 403 Client Error: Forbidden for url: https://www.biorxiv.org/lookup/doi/10.1101/2025.01.24.634773
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.29100/jipi.v10i3.6516: 403 Client Error: Forbidden for url: https://jurnal.stkippgritulungagung.ac.id/index.php/jipi/article/view/6516
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1145/3706468.3706552: 403 Client Error: Forbidden for url: https://dl.acm.org/doi/10.1145/3706468.3706552
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.3390/app15031636: 403 Client Error: Forbidden for url: https://www.mdpi.com/2076-3417/15/3/1636
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.2139/ssrn.5171030: 403 Client Error: Forbidden for url: https://papers.ssrn.com/sol3/papers.cfm?abstract_id=5171030
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1063/5.0265835: 403 Client Error: Forbidden for url: https://pubs.aip.org/aip/acp/article-lookup/doi/10.1063/5.0265835
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.3390/modelling6030071: 403 Client Error: Forbidden for url: https://www.mdpi.com/2673-3951/6/3/71
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1111/acel.70344: 403 Client Error: Forbidden for url: https://onlinelibrary.wiley.com/doi/10.1111/acel.70344
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1161/str.56.suppl_1.wp373: 403 Client Error: Forbidden for url: https://www.ahajournals.org/doi/10.1161/str.56.suppl_1.WP373
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1080/17508975.2025.2570941: 403 Client Error: Forbidden for url: https://www.tandfonline.com/doi/full/10.1080/17508975.2025.2570941
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.2139/ssrn.5586583: 403 Client Error: Forbidden for url: https://papers.ssrn.com/sol3/papers.cfm?abstract_id=5586583
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.3390/math13162581: 403 Client Error: Forbidden for url: https://www.mdpi.com/2227-7390/13/16/2581
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.2139/ssrn.5280401: 403 Client Error: Forbidden for url: https://papers.ssrn.com/sol3/papers.cfm?abstract_id=5280401
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.3390/biomimetics10030167: 403 Client Error: Forbidden for url: https://www.mdpi.com/2313-7673/10/3/167
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.3390/buildings15224129: 403 Client Error: Forbidden for url: https://www.mdpi.com/2075-5309/15/22/4129
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1093/humrep/deaf097.424: 403 Client Error: Forbidden for url: https://academic.oup.com/humrep/article/doi/10.1093/humrep/deaf097.424/8170397
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.52783/jns.v14.1733: HTTPSConnectionPool(host='jneonatalsurg.com', port=443): Max retries exceeded with url: /index.php/jns/article/view/1733 (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'jneonatalsurg.com'. (_ssl.c:1010)")))
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1061/nhrefo.nheng-2244: 403 Client Error: Forbidden for url: https://ascelibrary.org/doi/10.1061/NHREFO.NHENG-2244
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1080/02626667.2025.2530120: 403 Client Error: Forbidden for url: https://www.tandfonline.com/doi/full/10.1080/02626667.2025.2530120
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1101/2025.09.22.677729: 403 Client Error: Forbidden for url: https://www.biorxiv.org/lookup/doi/10.1101/2025.09.22.677729
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1101/2025.04.07.647541: 403 Client Error: Forbidden for url: https://www.biorxiv.org/lookup/doi/10.1101/2025.04.07.647541
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1504/ijgw.2025.147649: 403 Client Error: Forbidden for url: https://www.inderscienceonline.com/doi/abs/10.1504/IJGW.2025.147649
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.4236/jcc.2025.132013: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1101/2025.05.20.655104: 403 Client Error: Forbidden for url: https://www.biorxiv.org/lookup/doi/10.1101/2025.05.20.655104
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1039/9781837676583-00114: 403 Client Error: Forbidden for url: https://books.rsc.org/books/book/2318/chapter/8547612/Regulation-of-Pluripotent-Stem-Cell-Pluripotency
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.64898/2025.12.22.695316: 403 Client Error: Forbidden for url: https://www.biorxiv.org/lookup/doi/10.64898/2025.12.22.695316
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.3791/30183: 403 Client Error: Forbidden for url: https://app.jove.com/t/30183/long-term-orthotopic-transplantation-tumor-cells-into-zebrafish
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.33558/piksel.v13i1.10731: 403 Client Error: Forbidden for url: https://jurnal.unismabekasi.ac.id/index.php/piksel/article/view/10731
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1142/s0219467827500306: 403 Client Error: Forbidden for url: https://www.worldscientific.com/doi/10.1142/S0219467827500306
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1073/pnas.2406474122: 403 Client Error: Forbidden for url: https://pnas.org/doi/10.1073/pnas.2406474122
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.28932/jutisi.v11i1.10066: 403 Client Error: Forbidden for url: https://journal.maranatha.edu/index.php/jutisi/article/view/10066
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.51903/juritek.v5i3.5578: 403 Client Error: Forbidden for url: https://journalcenter.org/index.php/JURITEK/article/view/5578
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.3390/en18195060: 403 Client Error: Forbidden for url: https://www.mdpi.com/1996-1073/18/19/5060
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1111/coin.70078: 403 Client Error: Forbidden for url: https://onlinelibrary.wiley.com/doi/10.1111/coin.70078
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.54371/jiip.v8i10.9277: 403 Client Error: Forbidden for url: http://jiip.stkipyapisdompu.ac.id/jiip/index.php/JIIP/article/view/9277
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.3390/forecast7030045: 403 Client Error: Forbidden for url: https://www.mdpi.com/2571-9394/7/3/45
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.34133/bmr.0157: 403 Client Error: Forbidden for url: https://spj.science.org/doi/10.34133/bmr.0157
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.3791/31543: 403 Client Error: Forbidden for url: https://app.jove.com/t/31543/in-vitro-calcium-imaging-short-term-long-term-rat-hippocampal
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.22541/au.175648039.94197291/v1: 403 Client Error: Forbidden for url: https://www.authorea.com/users/828258/articles/1329910-spindle-cell-carcinoma-16-years-later-a-wake-up-call-for-long-term-oncology-surveillance?commit=591078ac20f1078f3c3933ef450e4a51d32852fe
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.5152/tepes.2025.25021: 404 Client Error: Not Found for url: https://tepesjournal.org/index.php/pub/article/view/148
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1504/ijiei.2025.150102: 403 Client Error: Forbidden for url: https://www.inderscienceonline.com/doi/abs/10.1504/IJIEI.2025.150102
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1142/s0219467827500884: 403 Client Error: Forbidden for url: https://www.worldscientific.com/doi/10.1142/S0219467827500884
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.12962/j23373520.v13i4.152727: HTTPConnectionPool(host='ejurnal.its.ac.id', port=80): Max retries exceeded with url: /index.php/sains_seni/article/view/152727 (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7a3c068ed760>: Failed to resolve 'ejurnal.its.ac.id' ([Errno -2] Name or service not known)"))
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1002/9781394272624.ch17: 403 Client Error: Forbidden for url: https://onlinelibrary.wiley.com/doi/10.1002/9781394272624.ch17
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1002/adfm.202526641: 403 Client Error: Forbidden for url: https://advanced.onlinelibrary.wiley.com/doi/10.1002/adfm.202526641
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1093/jimmun/vkae037: 403 Client Error: Forbidden for url: https://academic.oup.com/jimmunol/article/214/3/433/8030594
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1101/2025.05.07.652583: 403 Client Error: Forbidden for url: https://www.biorxiv.org/lookup/doi/10.1101/2025.05.07.652583
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.2139/ssrn.5317082: 403 Client Error: Forbidden for url: https://papers.ssrn.com/sol3/papers.cfm?abstract_id=5317082
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.2139/ssrn.5094239: 403 Client Error: Forbidden for url: https://papers.ssrn.com/sol3/papers.cfm?abstract_id=5094239
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.2139/ssrn.5332144: 403 Client Error: Forbidden for url: https://papers.ssrn.com/sol3/papers.cfm?abstract_id=5332144
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.3390/microplastics4020026: 403 Client Error: Forbidden for url: https://www.mdpi.com/2673-8929/4/2/26
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.2166/wst.2025.139: 403 Client Error: Forbidden for url: https://iwaponline.com/wst/article/92/7/1063/109491/Model-predictive-control-of-anaerobic-digestion
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1177/14759217241293994: 403 Client Error: Forbidden for url: https://journals.sagepub.com/doi/10.1177/14759217241293994
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1080/10589759.2025.2584629: 403 Client Error: Forbidden for url: https://www.tandfonline.com/doi/full/10.1080/10589759.2025.2584629
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1177/00202940251383644: 403 Client Error: Forbidden for url: https://journals.sagepub.com/doi/10.1177/00202940251383644
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.63682/jns.v14i19s.4789: HTTPSConnectionPool(host='jneonatalsurg.com', port=443): Max retries exceeded with url: /index.php/jns/article/view/4789 (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'jneonatalsurg.com'. (_ssl.c:1010)")))
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.61769/telematika.v20i1.742: HTTPSConnectionPool(host='202.138.229.150', port=443): Max retries exceeded with url: /index.php/telematika/article/view/742 (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: IP address mismatch, certificate is not valid for '202.138.229.150'. (_ssl.c:1010)")))
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.2139/ssrn.5120896: 403 Client Error: Forbidden for url: https://papers.ssrn.com/sol3/papers.cfm?abstract_id=5120896
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.3390/w17091380: 403 Client Error: Forbidden for url: https://www.mdpi.com/2073-4441/17/9/1380
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.26714/jsunimus.13.1.2025.74-84: 403 Client Error: Forbidden for url: https://jurnal.unimus.ac.id/index.php/statistik/article/view/16165
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.3390/s25020421: 403 Client Error: Forbidden for url: https://www.mdpi.com/1424-8220/25/2/421
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.2118/223787-ms: 403 Client Error: Forbidden for url: https://onepetro.org/SPEDC/proceedings/25DC/25DC/D011S004R005/642510
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.2139/ssrn.5096018: 403 Client Error: Forbidden for url: https://papers.ssrn.com/sol3/papers.cfm?abstract_id=5096018
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1101/2025.01.31.635927: 403 Client Error: Forbidden for url: https://www.biorxiv.org/lookup/doi/10.1101/2025.01.31.635927
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.51454/decode.v5i1.866: 468 Client Error:  for url: https://journal.umkendari.ac.id/decode/article/view/866
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.4218/etrij.2024-0256: 403 Client Error: Forbidden for url: https://onlinelibrary.wiley.com/doi/10.4218/etrij.2024-0256
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.2118/223940-pa: 403 Client Error: Forbidden for url: https://onepetro.org/SJ/article/30/03/1010/625269/A-Novel-Multihead-Attention-Enhanced-Convolutional
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.2139/ssrn.5576423: 403 Client Error: Forbidden for url: https://papers.ssrn.com/sol3/papers.cfm?abstract_id=5576423
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.21428/cb6ab371.d9462bc9: 403 Client Error: Forbidden for url: https://www.crimrxiv.com/pub/bkqo83zy
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1002/alz70855_106829: 403 Client Error: Forbidden for url: https://alz-journals.onlinelibrary.wiley.com/doi/10.1002/alz70855_106829
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1080/02331888.2025.2593401: 403 Client Error: Forbidden for url: https://www.tandfonline.com/doi/full/10.1080/02331888.2025.2593401
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1111/coin.70073: 403 Client Error: Forbidden for url: https://onlinelibrary.wiley.com/doi/10.1111/coin.70073
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.59400/sv2022: HTTPSConnectionPool(host='ojs.acad-pub.com', port=443): Max retries exceeded with url: /index.php/SV/article/view/2022 (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1010)')))
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.3390/app15020633: 403 Client Error: Forbidden for url: https://www.mdpi.com/2076-3417/15/2/633
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.1029/2024wr039659: 403 Client Error: Forbidden for url: https://agupubs.onlinelibrary.wiley.com/doi/10.1029/2024WR039659
# ERROR:__main__:Error extracting email from HTML https://doi.org/10.3390/pr13051308: 403 Client Error: Forbidden for url: https://www.mdpi.com/2227-9717/13/5/1308
# ✅ Processed 1949 papers for author extraction
#
# [5/5] Classifying affiliations...
# ✅ Saved 1949 candidates to authors_candidates.csv
#
# ================================================================================
# PIPELINE COMPLETE
# ================================================================================

# %%
print("\n📊 PIPELINE SUMMARY STATISTICS")
print("="*80)

# Check file existence
import os
files_to_check = [
    'papers_raw.csv',
    'papers_deduped.csv',
    'papers_master.csv',
    'authors_candidates.csv'
]

for filename in files_to_check:
    filepath = f'{BASE_PATH}/data/outputs/{filename}'
    exists = os.path.exists(filepath)
    print(f"{'✅' if exists else '❌'} {filename}: {'EXISTS' if exists else 'MISSING'}")

print("\n" + "-"*80)

# Load and verify papers_raw
df_raw_check = pd.read_csv(f'{BASE_PATH}/data/outputs/papers_raw.csv')
print(f"📄 papers_raw.csv: {len(df_raw_check)} rows")

# Verify papers_deduped
df_deduped_check = pd.read_csv(f'{BASE_PATH}/data/outputs/papers_deduped.csv')
print(f"📄 papers_deduped.csv: {len(df_deduped_check)} rows")
year_check = df_deduped_check['year'].unique()
print(f"   Years present: {year_check}")
assert all(y == TARGET_YEAR for y in year_check), f"ERROR: Found years other than {TARGET_YEAR}"

# Verify papers_master
df_master_check = pd.read_csv(f'{BASE_PATH}/data/outputs/papers_master.csv')
print(f"📄 papers_master.csv: {len(df_master_check)} rows")
assert 'pdf_url' in df_master_check.columns, "ERROR: Missing pdf_url column"
assert 'oa_status' in df_master_check.columns, "ERROR: Missing oa_status column"
papers_with_pdf = df_master_check['pdf_url'].notna().sum()
print(f"   Papers with PDF: {papers_with_pdf} ({papers_with_pdf/len(df_master_check)*100:.1f}%)")

# Verify authors_candidates
df_authors_check = pd.read_csv(f'{BASE_PATH}/data/outputs/authors_candidates.csv')
print(f"📄 authors_candidates.csv: {len(df_authors_check)} rows")
assert 'contact_email' in df_authors_check.columns, "ERROR: Missing contact_email column"
assert 'affiliation_type' in df_authors_check.columns, "ERROR: Missing affiliation_type column"
assert 'keep_candidate' in df_authors_check.columns, "ERROR: Missing keep_candidate column"

papers_with_email = df_authors_check['contact_email'].notna().sum()
print(f"   Papers with email: {papers_with_email} ({papers_with_email/len(df_authors_check)*100:.1f}%)")

# Classification breakdown
print("\n📊 Affiliation Classification:")
for aff_type in ['Academic', 'Industry', 'Unknown']:
    count = (df_authors_check['affiliation_type'] == aff_type).sum()
    print(f"   {aff_type}: {count}")

# Keep/drop breakdown
kept = df_authors_check['keep_candidate'].sum()
dropped = len(df_authors_check) - kept
print(f"\n✅ Candidates kept: {kept}")
print(f"❌ Candidates dropped: {dropped}")

# Drop reasons
if 'drop_reason' in df_authors_check.columns:
    print("\n📋 Drop Reasons:")
    drop_reasons = df_authors_check[df_authors_check['drop_reason'] != '']['drop_reason'].value_counts()
    for reason, count in drop_reasons.items():
        print(f"   {reason}: {count}")

print("\n" + "="*80)
print("✅ ALL VERIFICATION CHECKS PASSED")
print("="*80)
